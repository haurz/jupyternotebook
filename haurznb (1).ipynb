# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **hiba anis**
#
# student

# %% [markdown]
# *ive been quite lazy after i graduated my high school so i chose data science as my course to see what im really inerested in before i start a bachelor degree*

# %% [markdown]
# ### *a subtraction equation*

# %%
five=5
three=3
print(five-three)
# Out:
# 2

# %% [markdown]
# To learn more about [jupyternotebook](https://github.com/jupyter/jupyter/wiki) click on it.
#
# | first name | last name |
# | ------     | ------    |
# | hiba       | zubairi   |
#
# [![fantasy](https://i.pinimg.com/564x/32/48/29/3248291b7485545a2f7c7ffd1358db30.jpg)
